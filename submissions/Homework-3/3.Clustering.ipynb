# %% [markdown]
# (In order to load the stylesheet of this notebook, execute the last code cell in this notebook)

# %% [markdown]
# # Clustering the data from the Mayor's 24-hour hotline in Boston

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this assignment, we will do a clustering analysis on the 311 calls that we used in the previous homework. We will focus on choosing a value for k, clustering based on multiple features and detecting outliers.
#
# ---------------------------

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp

import sklearn.datasets as sk_data
import sklearn.metrics as metrics
from sklearn.cluster import KMeans

# %%
boston = pd.read_csv('../Homework-2/cases_2015.csv')

# %% [markdown]
# ## Step 1. Simple clustering

# %% [markdown]
# The first thing that we will try is to cluster the geolocation data of the calls. The geolocation of a record consists of a pair `(latitude, longitude)`, which represents the position of the record on the map. Since the dataset that we have spans only a small geographic location, i.e. Boston, we will use the Euclidean distance when measuring how close two points are. Techinically, we should pick a [projection](https://github.com/mbostock/d3/wiki/Geo-Projections) in order to transform the data into 2d, and measure  the Euclidean distance in the projected space.

# %% [markdown]
# Since we are dealing with numeric data, we might consider centering and normalizing them. In order to do that, check the [StandardScaler](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html#sklearn.preprocessing.StandardScaler) from `scikit-learn`.

# %% [markdown]
# For exampe, the result of a clustering with 10 clusters is the following:
#
#
# ![A clustering of the locations of the calls for k=10](clusters10.png)

# %% [markdown]
# Filter the dataset to get the latitude and longitude, transform it as required and run the k-means clustering algorithm. Argue about the number of clusters you used. **(pts 50)**

# %%
from sklearn.preprocessing import StandardScaler
boston_loc=boston[['LONGITUDE','LATITUDE']]
scaler = StandardScaler()
bfit=scaler.fit_transform(boston_loc)

kmeans = KMeans(init='k-means++', n_clusters=18,n_init=10)
kmeans.fit_predict(bfit)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
error = kmeans.inertia_
print error
print labels
# Out:
# 3181.22533045
# [5 6 6 ..., 4 5 4]

# %%
X=scaler.fit_transform(boston_loc['LONGITUDE'])
Y=scaler.fit_transform(boston_loc['LATITUDE'])

# %%
fig, ax = plt.subplots(1,1,figsize=(23,23))
# I have 10 clusters, so I need 10 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together
cmap = sns.color_palette("bright", n_colors=8)
cmap.extend(sns.hls_palette(n_colors=18, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(labels)):
    point_indices = np.where(labels == label)[0]
    point_indices = point_indices.tolist()
    plt.scatter(X[point_indices], Y[point_indices], s=25, alpha=0.5, c=cmap[i], marker='o')

# %%
'''
To Cluster The geographical data specifically, I used a total of 18 clusters. I know from a little bit of resaerch that boston is
officially divided into 23 neighborhoods. However spiltting into exactly 23 clusters led to many of the large neighborhoods to the
south side like West Roxburry becoming spilt apart. 18 clusters splits the lower portions of the scatter plot accurately at the cost
of incorrect neighborhoods in the downtown area. However I feel that this better represents the actual shape of the city a bit better.
One interesting part this clustering revealed was that the north west part of boston: namely allston and brighton are two distinct
neighborhoods which I probably wouldnt have guessed based solely on geographical location
'''

# %% [markdown]
# ## Step 2. Using multiple features

# %% [markdown]
# The next step in our analysis is to use more features than just the geolocation of a record (whose clustering only gives us information about the neighborhoods, which should not be a huge revelation!) Filter the dataset to get more features, transform them as required and compute another clustering. You should argue about the quality of your clustering and use domain knowledge (i.e. the fact that you are locals) to explore the clusters you produced and present them to the reader. **(pts 30)**

# %%
print boston.SUBJECT.value_counts()
# Out:
# Public Works Department              30052
# Inspectional Services                10186
# Mayor's 24 Hour Hotline               2688
# Transportation - Traffic Division     1758
# Parks & Recreation Department          622
# Property Management                    290
# Boston Public School                   289
# Animal Control                         264
# Civil Rights                           258
# Boston Water & Sewer Commission        137
# Disability Department                   89
# Youthline                               62
# Boston Police Department                 3
# dtype: int64

# %%
c2=boston[['LONGITUDE','LATITUDE','SUBJECT','Source','OPEN_DT','CASE_TITLE']]
scaler = StandardScaler()
X=scaler.fit_transform(boston_loc['LONGITUDE'])
Y=scaler.fit_transform(boston_loc['LATITUDE'])

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words='english', min_df=4, max_df=0.8)
data = vectorizer.fit_transform(c2['SUBJECT'])

k=13
kmeans = KMeans(init='k-means++', n_clusters=k,n_init=10)
kmeans.fit_predict(data)
centroids = kmeans.cluster_centers_
labels = kmeans.labels_
error = kmeans.inertia_


fig, ax = plt.subplots(1,1,figsize=(23,23))
# I have 10 clusters, so I need 10 colors. Each colormap can produce 10 colors
# so I am mixing two colormaps that I tested that work well together
cmap = sns.color_palette("bright", n_colors=8)
cmap.extend(sns.hls_palette(n_colors=18, h=0.7, l=0.4, s=0.8))

# for each label, isolate the points of that label and plot them with the same color
for i, label in enumerate(set(labels)):
    point_indices = np.where(labels == label)[0]
    point_indices = point_indices.tolist()
    plt.scatter(X[point_indices], Y[point_indices], s=25, alpha=0.5, c=cmap[i], marker='o')
plt.legend()
plt.show()

# %% [markdown]
# -----

# %%
list(labels).count(2)

'''

'''
# Out:
# 2688

# %% [markdown]
# ## Step 3. Detecting outliers

# %% [markdown]
# Now that we have a clustering of the records in the dataset, we can detect the outlying ones. These are the ones who are the farthest from the centroids of their clusters. Track them down and describe any interesting observations that you can make. **(pts 20)**

# %%
# Code for setting the style of the notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("../../theme/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=EB+Garamond' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     .code_cell {
#         width: 105ex !important ;
#         margin-bottom: 15px !important;
#     }
#     div.cell {
#         margin-left: auto;
#         margin-right: auto;
#         width: 70%;
#     }
#     div.cell.selected {
#         border: thin rgba(171, 171, 171, 0.5) dashed;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'EB Garamond', serif;
#     }
#     h3 {
#         font-family: 'EB Garamond', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#     }
#     h4 {
#         font-family: 'EB Garamond', serif;
#     }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render {
#         font-family: 'EB Garamond',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 145%;
#         font-size: 140%;
#     }
#     div.input_area {
#         border-color: rgba(0,0,0,0.10) !important;
#         background: #fafafa;
#     }
#     .CodeMirror {
#             font-family: "Source Code Pro";
#             font-size: 90%;
#     }
#     .prompt {
#         display: None;
#     }
#     .output {
#         padding-left: 50px;
#         padding-top: 5px;
#     }
#     .output_wrapper {
#         padding-left: 5px;
#         padding-top: inherit;
#     }
#     div.output_scroll {
#         width: inherit;
#     }
#     .inner_cell {
#         padding-left: 5px;
#     }
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
#         line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .warning {
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
